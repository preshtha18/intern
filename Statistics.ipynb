# %%
#mean value
import numpy as np
data_mean=[10,20,30,40,50,60,70,80]
mean_value=np.mean(data_mean)
print(f"Mean:{mean_value}")
# Out:
# Mean:45.0

# %%
#median value
import numpy as np
data_median=[10,20,30,40,50,60,70,80]
median_value=np.median(data_median)
print(f"Median:{median_value}")
# Out:
# Median:45.0

# %%
#Mode
import statistics
data = [1, 2, 2, 3, 4, 4, 4, 5, 6]
mode_value = statistics.mode(data)
print(f"The mode of the dataset is: {mode_value}")
# Out:
# The mode of the dataset is: 4

# %%
#Outlier
data_outliers = [10, 12, 14, 15, 16, 18, 19, 20, 100]  # 100 is an outlier
Q1 = np.percentile(data_outliers, 25)
Q3 = np.percentile(data_outliers, 75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = [x for x in data_outliers if x < lower_bound or x > upper_bound]
print(f"Outliers: {outliers}")
# Out:
# Outliers: [100]

# %%
#Variance
import numpy as np
import statistics
data=[10,12,13,14,15,16,17,18]
variance_numpy=np.var(data,ddof=0)
variance_numpy_sample=np.var(data,ddof=1)
variance_statistics=statistics.variance(data)
variance_statistics_population=statistics.pvariance(data)
print(f"Variance (NumPy - Population): {variance_numpy}")
print(f"Variance (NumPy - Sample): {variance_numpy_sample}")
print(f"Variance (Statistics - Sample): {variance_statistics}")
print(f"Variance (Statistics - Population): {variance_statistics_population}")
# Out:
# Variance (NumPy - Population): 6.234375
# Variance (NumPy - Sample): 7.125
# Variance (Statistics - Sample): 7.125
# Variance (Statistics - Population): 6.234375

# %%
#standard deviation
import numpy as np
import statistics
data = [10, 12, 14, 15, 16, 18, 19, 20]
std_dev_numpy = np.std(data, ddof=0)  
std_dev_numpy_sample = np.std(data, ddof=1)  
std_dev_statistics = statistics.stdev(data)  
std_dev_statistics_population = statistics.pstdev(data)  
print(f"Standard Deviation (NumPy - Population): {std_dev_numpy}")
print(f"Standard Deviation (NumPy - Sample): {std_dev_numpy_sample}")
print(f"Standard Deviation (Statistics - Sample): {std_dev_statistics}")
print(f"Standard Deviation (Statistics - Population): {std_dev_statistics_population}")
# Out:
# Standard Deviation (NumPy - Population): 3.24037034920393
# Standard Deviation (NumPy - Sample): 3.4641016151377544
# Standard Deviation (Statistics - Sample): 3.4641016151377544
# Standard Deviation (Statistics - Population): 3.24037034920393

# %%
#normal distribution
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(42)
mean = 0  
std_dev = 1  
sample_size = 1000  
data = np.random.normal(mean, std_dev, sample_size)
plt.figure(figsize=(10, 6))
sns.histplot(data, bins=30, kde=True, color='green', stat='density')
plt.title('Normal Distribution (Mean = 0, Std Dev = 1)')
plt.xlabel('Value')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\preshtha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Skewness
from scipy.stats import skew
dataset=[10,21,34,22,15,71,40,12,16,90,33,25,37,33,23]
print(skew(dataset,axis=0,bias=True))
# Out:
# 1.54226964614397

# %%
#kurtosis
from scipy.stats import kurtosis
dataset=[10,21,34,22,15,71,40,12,16,90,33,25,37,33,23]
print(kurtosis(dataset,axis=0,bias=True))
# Out:
# 1.6262655081871564

# %%
#Probablity normal distribution
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
data =stats.norm(scale=1, loc=0).rvs(1000)
ax=sns.distplot(data,bins=50,kde=True,color="blue",hist_kws={"linewidth":15,'alpha':1})
ax.set(xlabel='Normal Distribution',ylabel='Frequency')
plt.show()
# Out:
# C:\Users\preshtha\AppData\Local\Temp\ipykernel_11608\2005991235.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(data,bins=50,kde=True,color="blue",hist_kws={"linewidth":15,'alpha':1})
# C:\Users\preshtha\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Bionomial distribution
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
n,p=10, .6
data=np.random.binomial(n,p,10000)
ax=sns.distplot(data,bins=20,kde=False,color='pink',hist_kws={"linewidth":15,'alpha':1})
ax.set(xlabel='Binomial Distribution',ylabel='Frequency')
plt.show()
# Out:
# C:\Users\preshtha\AppData\Local\Temp\ipykernel_11608\718121574.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(data,bins=20,kde=False,color='pink',hist_kws={"linewidth":15,'alpha':1})

# %%
#poisson distribution
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
poisson_data=np.random.poisson(lam=5,size=1000)
ax=sns.distplot(poisson_data,kde=False,color='pink')
ax.set(xlabel='Poisson Distribution',ylabel='Frequency')
plt.show()
# Out:
# C:\Users\preshtha\AppData\Local\Temp\ipykernel_11608\3771322209.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(poisson_data,kde=False,color='pink')

# %%
#one tailed z-test hypothesis
import numpy as np
import scipy.stats as stats
sample_mean=100
population_mean=100
population_std=15
sample_size=50
alpha=0.5
z_score=(sample_mean-population_mean)/(population_std/np.sqrt(50))
print('Z-score :',z_score)
z_critical=stats.norm.ppf(1-alpha)
print('critical Z-score :',z_critical)
if z_score > z_critical:
    print("Reject NULL hypothesis")
else:
    print("Fail to reject Null hypothesis")
p_value=1-stats.norm.cdf(z_score)
print('p-value :',p_value)
if p_value <  alpha:
    print("Reject Null Hypothesis")
else:
  print("Fail to Reject Null Hypothesis")
# Out:
# Z-score : 0.0
# critical Z-score : 0.0
# Fail to reject Null hypothesis
# p-value : 0.5
# Fail to Reject Null Hypothesis

# %%
#Two sampled z=test
import numpy as np
import scipy.stats as stats
#Group a (offline class)
n1=20
x1=30
y1=40
#Group b (online class)
n2=15
x2=25
y2=35

D=0

alpha=0.05

z_score==((x1-x2)-D)/np.sqrt((y1**2/n1)+(y2**2/n2))
print('Z-score :',np.abs(z_score))
z_critical=stats.norm.ppf(1-alpha/2)
print('Critical z_score: ',z_critical)
if np.abs(z_score)>z_critical:
    print("""Reject the null hypothesis.
There is a significant difference between the online and offline classes.""")
else:
    print("""Fail to reject the null hypothesis.
There is not enough evidence to suggest a significant difference between the online and offline classes.""")

p_value=2*(1-stats.norm.cdf(np.abs(z_score)))
print('P-value :',p_value)
if p_value < alpha:
    print("""Reject the null hypothesis.
There is a significant difference between the online and offline classes.""")
else:
    print("""Fail to reject the null hypothesis.
There is not enough evidence to suggest significant difference between the online and offline classes.""")
# Out:
# Z-score : 0.0
# Critical z_score:  1.959963984540054
# Fail to reject the null hypothesis.
# There is not enough evidence to suggest a significant difference between the online and offline classes.
# P-value : 1.0
# Fail to reject the null hypothesis.
# There is not enough evidence to suggest significant difference between the online and offline classes.

# %%
#Chi square distribution
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
df=2
alpha=0.05
critical_value=stats.chi2.ppf(1-alpha,df)
critical_value
# Out:
# 5.991464547107979

# %%
#visualize the chi-square distribution and Critical Region, with python code.
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
df = 2
alpha = 0.05
critical_value = stats.chi2.ppf(1 - alpha, df)
calculated_chi_square = 3.747
x = np.linspace(0, 10, 1000)
y = stats.chi2.pdf(x, df)
plt.plot(x, y, label='Chi-Square Distribution (df=2)')
plt.fill_between(x, y, where=(x > critical_value), color='red', alpha=0.5, label='Critical Region')
plt.axvline(calculated_chi_square, color='blue', linestyle='dashed', label='Calculated Chi-Square')
plt.axvline(critical_value, color='green', linestyle='dashed', label='Critical Value')
plt.title('Chi-Square Distribution and Critical Region')
plt.xlabel('Chi-Square Value')
plt.ylabel('Probability Density Function')
plt.legend()
plt.show()

# %%
#implementation of Chi-Square feature selection
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
iris=load_iris()
X=iris.data
y=iris.target
column_names=[f'feature_{i}' for i in range (X.shape[1])]
df=pd.DataFrame(X, columns=column_names)
df['target']=y
print("Original Dataset :")
print(df.head())
k=2
chi2_selector=SelectKBest(chi2,k=k)
X_new=chi2_selector.fit_transform(X,y)
selected_features = df.columns[:-1][chi2_selector.get_support()]
print("\nSelected Features:")
print(selected_features)
# Out:
# Original Dataset :
#    feature_0  feature_1  feature_2  feature_3  target
# 0        5.1        3.5        1.4        0.2       0
# 1        4.9        3.0        1.4        0.2       0
# 2        4.7        3.2        1.3        0.2       0
# 3        4.6        3.1        1.5        0.2       0
# 4        5.0        3.6        1.4        0.2       0
#
# Selected Features:
# Index(['feature_2', 'feature_3'], dtype='object')

# %%
#linear regression
from scipy.stats import stats
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
slope,intercept,r,p,std_err=stats.linregress(x,y)
def myfunc(x):
    return slope*x+intercept
speed = myfunc(10)
print(speed)
# Out:
# 85.59308314937454
# C:\Users\preshtha\AppData\Local\Temp\ipykernel_11608\3194098633.py:5: DeprecationWarning: Please use `linregress` from the `scipy.stats` namespace, the `scipy.stats.stats` namespace is deprecated.
#   slope,intercept,r,p,std_err=stats.linregress(x,y)

# %%
import matplotlib.pyplot as plt
from scipy.stats import stats
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
slope, intercept, r, p, std_err = stats.linregress(x, y)
def myfunc(x):
  return slope * x + intercept
mymodel = list(map(myfunc, x))
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()
# Out:
# C:\Users\preshtha\AppData\Local\Temp\ipykernel_11608\2873236429.py:5: DeprecationWarning: Please use `linregress` from the `scipy.stats` namespace, the `scipy.stats.stats` namespace is deprecated.
#   slope, intercept, r, p, std_err = stats.linregress(x, y)

# %%
#plynomial regression
import numpy 
import matplotlib.pyplot as plt
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]
mymodel=numpy.poly1d(numpy.polyfit(x,y,3))
myline=numpy.linspace(1,22,100)
plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
#multiple regression
import pandas 
from sklearn import linear_model
df=pandas.read_csv(r'C:\Users\preshtha\Documents\dataset\data.csv')
X = df[['Weight', 'Volume']]
y = df['CO2']
regr = linear_model.LinearRegression()
regr.fit(X, y)
predictedCO2 = regr.predict([[2300, 1300]])
print(predictedCO2)
# Out:
# [153.99673344]
# C:\Users\preshtha\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#confusion metrics
import matplotlib.pyplot as plt
import numpy
from sklearn import metrics
actual = numpy.random.binomial(1,.9,size = 1000)
predicted = numpy.random.binomial(1,.9,size = 1000)
confusion_matrix = metrics.confusion_matrix(actual, predicted)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [0, 1])
cm_display.plot()
plt.show()

# %%
#hierarchical clustering
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
x = [4, 5, 10, 4, 3, 11, 14 , 6, 10, 12]
y = [21, 19, 24, 17, 16, 25, 24, 22, 21, 21]
data=list(zip(x,y))
linkage_data=linkage(data,method='ward',metric='euclidean')
dendrogram(linkage_data)
plt.show()

# %%
#categorical data
import pandas as pd
cars=pd.read_csv(r'C:\Users\preshtha\Documents\dataset\data.csv')
print(cars.to_string())
# Out:
#            Car       Model  Volume  Weight  CO2
# 0       Toyota        Aygo    1000     790   99
# 1   Mitsubishi  Space Star    1200    1160   95
# 2        Skoda      Citigo    1000     929   95
# 3         Fiat         500     900     865   90
# 4         Mini      Cooper    1500    1140  105
# 5           VW         Up!    1000     929  105
# 6        Skoda       Fabia    1400    1109   90
# 7     Mercedes     A-Class    1500    1365   92
# 8         Ford      Fiesta    1500    1112   98
# 9         Audi          A1    1600    1150   99
# 10     Hyundai         I20    1100     980   99
# 11      Suzuki       Swift    1300     990  101
# 12        Ford      Fiesta    1000    1112   99
# 13       Honda       Civic    1600    1252   94
# 14      Hundai         I30    1600    1326   97
# 15        Opel       Astra    1600    1330   97
# 16         BMW           1    1600    1365   99
# 17       Mazda           3    2200    1280  104
# 18       Skoda       Rapid    1600    1119  104
# ...

# %%
#k-means elbow method
from sklearn.cluster import KMeans
data=list(zip(x,y))
inertias=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i)
    kmeans.fit(data)
    inertias.append(kmeans.inertia_)
plt.plot(range(1,11), inertias, marker='o')
plt.title('Elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()
# Out:
# C:\Users\preshtha\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\preshtha\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\preshtha\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...
