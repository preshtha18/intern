# %%
import pandas as pd
df=pd.read_csv('D:\inter file\data.csv')
print(df.to_string())
# Out:
#     Duration,Pulse,Maxpulse,Calories  Unnamed: 1  Unnamed: 2       Duration  Pulse  Maxpulse  Calories
# 0                 60,11,01,30,409.10         NaN         NaN  0          60    110       130     409.1
# 1                 60,11,71,45,479.00         NaN         NaN  1          60    117       145     479.0
# 2                 60,10,31,35,340.00         NaN         NaN  2          60    103       135     340.0
# 3                 45,10,91,75,282.40         NaN         NaN  3          45    109       175     282.4
# 4                 45,11,71,48,406.00         NaN         NaN  4          45    117       148     406.0
# 5                 60,10,21,27,300.50         NaN         NaN  5          60    102       127     300.5
# 6                 60,11,01,36,374.00         NaN         NaN  6          60    110       136     374.0
# 7                 45,10,41,34,253.30         NaN         NaN  7          45    104       134     253.3
# ...

# %%
import pandas as pd
mydataset={
    'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}
myvar=pd.DataFrame(mydataset)
print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.1.4

# %%
#Pandas series
import pandas as pd
a=[1,2,7]
myvar=pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    2
# 2    7
# dtype: int64

# %%
import pandas as pd
a=[1,2,7]
myvar=pd.Series(a)
print(myvar[1])
# Out:
# 2

# %%
#create label
import pandas as pd
a=[1,2,7]
myvar=pd.Series(a,index=["x","y","z"])
print(myvar)
# Out:
# x    1
# y    2
# z    7
# dtype: int64

# %%
#Key/values as series
import pandas as pd
calories={"day1":140,"day2":200,"day3":130}
myvar=pd.Series(calories)
print(myvar)
# Out:
# day1    140
# day2    200
# day3    130
# dtype: int64

# %%
#Data Frame
import pandas as pd
data={
    "calories":[140,200,130],
    "duration":[50,40,45]
}
myvar=pd.DataFrame(data)
print(myvar)
# Out:
#    calories  duration
# 0       140        50
# 1       200        40
# 2       130        45

# %%
#Locate raw in datafram
import pandas as pd
data={
    "calories":[140,200,130],
    "duration":[50,40,45]
}
df=pd.DataFrame(data)
print(df.loc[1])
# Out:
# calories    200
# duration     40
# Name: 1, dtype: int64

# %%
import pandas as pd
data={
    "calories":[140,200,130],
    "duration":[50,40,45]
}
df=pd.DataFrame(data)
print(df.loc[[0,1]])
# Out:
#    calories  duration
# 0       140        50
# 1       200        40

# %%
#Named index
import pandas as pd
data={
    "calories":[140,200,130],
    "duration":[50,40,45]
}
df=pd.DataFrame(data,index=["day1","day2","day3"])
print(df)
# Out:
#       calories  duration
# day1       140        50
# day2       200        40
# day3       130        45

# %%
#Located index value
import pandas as pd
data={
    "calories":[140,200,130],
    "duration":[50,40,45]
}
df=pd.DataFrame(data,index=["day1","day2","day3"])
print(df.loc["day3"])
# Out:
# calories    130
# duration     45
# Name: day3, dtype: int64

# %%
import pandas as pd

pd.options.display.max_rows = 9999

df=pd.read_csv('D:\inter file\data.csv')

print(df)
# Out:
#     Duration,Pulse,Maxpulse,Calories  Unnamed: 1  Unnamed: 2  \
# 0                 60,11,01,30,409.10         NaN         NaN
# 1                 60,11,71,45,479.00         NaN         NaN
# 2                 60,10,31,35,340.00         NaN         NaN
# 3                 45,10,91,75,282.40         NaN         NaN
# 4                 45,11,71,48,406.00         NaN         NaN
# 5                 60,10,21,27,300.50         NaN         NaN
# 6                 60,11,01,36,374.00         NaN         NaN
# 7                 45,10,41,34,253.30         NaN         NaN
# 8                 30,10,91,33,195.10         NaN         NaN
# 9                  6,09,81,24,269.00         NaN         NaN
# 10                60,10,31,47,329.30         NaN         NaN
# 11                60,10,01,20,250.70         NaN         NaN
# 12                60,10,61,28,345.30         NaN         NaN
# 13                60,10,41,32,379.30         NaN         NaN
# ...

# %%
#display max row
import pandas as pd
print(pd.options.display.max_rows)
# Out:
# 60

# %%
import pandas as pd
pd.options.display.max_rows=99
df=pd.read_csv('D:\inter file\data.csv')
print(df)
# Out:
#     Duration,Pulse,Maxpulse,Calories  Unnamed: 1  Unnamed: 2  \
# 0                 60,11,01,30,409.10         NaN         NaN
# 1                 60,11,71,45,479.00         NaN         NaN
# 2                 60,10,31,35,340.00         NaN         NaN
# 3                 45,10,91,75,282.40         NaN         NaN
# 4                 45,11,71,48,406.00         NaN         NaN
# ..                               ...         ...         ...
# 164               60,10,51,40,290.80         NaN         NaN
# 165               60,11,01,45,300.40         NaN         NaN
# 166               60,11,51,45,310.20         NaN         NaN
# 167               75,12,01,50,320.40         NaN         NaN
# 168               75,12,51,50,330.40         NaN         NaN
#
#           Duration  Pulse  Maxpulse  Calories
# 0    0          60    110       130     409.1
# 1    1          60    117       145     479.0
# 2    2          60    103       135     340.0
# ...

# %%
import pandas as pd
data={
    "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}
df=pd.DataFrame(data)
print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
#Viewing the data
import pandas as pd
df=pd.read_csv('D:\inter file\data.csv')
print(df.head(10))
# Out:
#   Duration,Pulse,Maxpulse,Calories  Unnamed: 1  Unnamed: 2  \
# 0               60,11,01,30,409.10         NaN         NaN
# 1               60,11,71,45,479.00         NaN         NaN
# 2               60,10,31,35,340.00         NaN         NaN
# 3               45,10,91,75,282.40         NaN         NaN
# 4               45,11,71,48,406.00         NaN         NaN
# 5               60,10,21,27,300.50         NaN         NaN
# 6               60,11,01,36,374.00         NaN         NaN
# 7               45,10,41,34,253.30         NaN         NaN
# 8               30,10,91,33,195.10         NaN         NaN
# 9                6,09,81,24,269.00         NaN         NaN
#
#         Duration  Pulse  Maxpulse  Calories
# 0  0          60    110       130     409.1
# 1  1          60    117       145     479.0
# 2  2          60    103       135     340.0
# 3  3          45    109       175     282.4
# 4  4          45    117       148     406.0
# 5  5          60    102       127     300.5
# ...

# %%
import pandas as pd
df=pd.read_csv('D:\inter file\data.csv')
print(df.tail())
# Out:
#     Duration,Pulse,Maxpulse,Calories  Unnamed: 1  Unnamed: 2  \
# 164               60,10,51,40,290.80         NaN         NaN
# 165               60,11,01,45,300.40         NaN         NaN
# 166               60,11,51,45,310.20         NaN         NaN
# 167               75,12,01,50,320.40         NaN         NaN
# 168               75,12,51,50,330.40         NaN         NaN
#
#           Duration  Pulse  Maxpulse  Calories
# 164  164        60    105       140     290.8
# 165  165        60    110       145     300.4
# 166  166        60    115       145     310.2
# 167  167        75    120       150     320.4
# 168  168        75    125       150     330.4

# %%
import pandas as pd
df=pd.read_csv('D:\inter file\data.csv')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Duration,Pulse,Maxpulse,Calories          169 non-null    object
#  1   Unnamed: 1                                0 non-null      float64
#  2   Unnamed: 2                                0 non-null      float64
#  3        Duration  Pulse  Maxpulse  Calories  169 non-null    object
# dtypes: float64(2), object(2)
# memory usage: 5.4+ KB
# None
